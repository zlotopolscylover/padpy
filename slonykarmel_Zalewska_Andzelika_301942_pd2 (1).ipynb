# %%
import pandas as pd
import numpy as np

# %%
Users = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/Users.csv',
                      error_bad_lines=False,
                      comment="#")
Badges = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/Badges.csv',
                      error_bad_lines=False,
                      comment="#")
Comments = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/Comments.csv',
                      error_bad_lines=False,
                      comment="#")
PostLinks = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/PostLinks.csv,
                      error_bad_lines=False,
                      comment="#")
Posts = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/Posts.csv',
                      error_bad_lines=False,
                      comment="#")
Tags = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/Tags.csv',
                      error_bad_lines=False,
                      comment="#")
Votes = pd.read_csv('C:/Users/Ja/Desktop/Python/PD2/Votes.csv',
                      error_bad_lines=False,
                      comment="#")

# %%
import tempfile
import os
baza = os.path.join(tempfile.mkdtemp(), "baza.db")

if os.path.isfile(baza):
    os.remove(baza)

import sqlite3
conn = sqlite3.connect(baza)

# %%
Badges.to_sql("Badges", conn, index=False)
Comments.to_sql("Comments", conn,index=False)
PostLinks.to_sql("PostLinks", conn,index=False)
Posts.to_sql("Posts", conn,index=False)
Tags.to_sql("Tags", conn,index=False)
Users.to_sql("Users", conn,index=False)
Votes.to_sql("Votes", conn,index=False)

# %% [markdown]
# # Zadanie 1

# %% [markdown]
# Interpretacja: Z tablicy z głosami zliczamy, ile głosów typu 2 ("UpMod") otrzymał każdy post.

# %%
df_sql_1 = pd.read_sql_query("""
SELECT PostId, COUNT(*) AS UpVotes 
FROM Votes 
WHERE VoteTypeId=2 
GROUP BY PostId""", conn)

# %%
df_pd_1 = Votes.loc[(Votes.VoteTypeId==2)] \
            .groupby("PostId") \
            .size() \
            .reset_index(name = "UpVotes")
df_pd_1
# Out:
#        PostId  UpVotes
# 0           1       42
# 1           2       13
# 2           3       10
# 3           4       16
# 4           5       31
# 5           6       22
# 6           7        4
# 7           8       10
# 8           9        3
# 9          10        5
# 10         12        3
# 11         13        9
# 12         14       16
# 13         15        2
# 14         16        7
# 15         17       10
# 16         18       12
# 17         19        1
# 18         20       15
# 19         21        1
# 20         22        2
# 21         23       16
# 22         24       35
# 23         25        5
# 24         26       21
# 25         27       53
# 26         28       15
# 27         29       42
# 28         30        1
# 29         31        5
# ...       ...      ...
# 41751   63891        5
# 41752   63892        2
# 41753   63893        1
# 41754   63895        2
# 41755   63897        1
# 41756   63898        2
# 41757   63900        1
# 41758   63902        2
# 41759   63904        3
# 41760   63910        3
# 41761   63911        2
# 41762   63912        1
# 41763   63913        4
# 41764   63914        2
# 41765   63915        1
# 41766   63916        1
# 41767   63918        1
# 41768   63921        1
# 41769   63922        1
# 41770   63923        1
# 41771   63924        4
# 41772   63926        1
# 41773   63927        1
# 41774   63929        1
# 41775   63931        2
# 41776   63933        2
# 41777   63934        1
# 41778   63939        1
# 41779   63940        1
# 41780   63941        1
#
# [41781 rows x 2 columns]

# %%
df_sql_1.__class__
# Out:
# pandas.core.frame.DataFrame

# %%
df_pd_1.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_pd_1.equals(df_sql_1)
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe.

# %% [markdown]
# # Zadanie 2

# %% [markdown]
# Interpretacja: W tym zapytaniu otrzymujemy informację o tytule postu z pytaniem (PostTypeId=1), jego wyniku (Score), liczbie odsłon (ViewCount) oraz o tym, ile osób oznaczyło go jako "ulubiony" (FavoriteCount), ale tylko jeśli post takich odznaczeń miał conajmniej 25, a odsłon conajmniej 10000.

# %%
df_sql_2 = pd.read_sql_query("""
SELECT Title, Score, ViewCount, FavoriteCount 
FROM Posts 
WHERE PostTypeId=1 AND FavoriteCount >= 25 AND ViewCount>=10000""", conn)

# %%
df_pd_2 = Posts.loc[(Posts.PostTypeId==1) & (Posts.FavoriteCount>=25) & (Posts.ViewCount>=10000), ["Title","Score","ViewCount","FavoriteCount"]].reset_index(drop=True)
df_pd_2
# Out:
#                                                Title  Score  ViewCount  \
# 0  Terminology index - a list of bike part names ...    165   129577.0
# 1           How to clean up at work after a commute?    101    40669.0
# 2           What's your most useful cycle accessory?     35    10024.0
# 3                        Why ride a fixed-gear bike?    171   196543.0
# 4  How do I deal with a dog chasing me when I'm t...    109    50035.0
#
#    FavoriteCount
# 0          136.0
# 1           25.0
# 2           30.0
# 3           46.0
# 4           32.0

# %%
df_pd_2.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_pd_2.equals(df_sql_2)
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe.

# %% [markdown]
# # Zadanie 3

# %% [markdown]
# Interpretacja: Tabelę z tagami łączymy z tabelą postów i użytkowników. Wybieramy z nich informacje dotyczące nazwy tagu,
# ilości jego wystąpienia, użytkownika - twórcy danego tagu, pochodzeniu użytkownika oraz jego nicku. Wybieramy tylko posty tych użytkowników, których OwnerUserId jest różne od -1, co prawdopodobnie dotyczy użytkowników nieznanych. Dodatkowo sortujemy po ilości wystąpienia tagu (Count), co daje nam ranking tagów z dodatkową informacją o użytkowniku, który go stworzył, pochodzeniu użytkownika i jego nicku.

# %%
df_sql_3 = pd.read_sql_query("""SELECT Tags.TagName, Tags.Count, Posts.OwnerUserId,Users.Location, Users.DisplayName 
FROM Tags
JOIN Posts ON Posts.Id=Tags.WikiPostId
JOIN Users ON Users.AccountId=Posts.OwnerUserId
WHERE OwnerUserId != -1
ORDER BY Count DESC""", conn)

# %%
tmp = pd.merge(pd.merge(Tags, Posts, left_on = 'WikiPostId', right_on = 'Id', how='inner'),Users, left_on = 'OwnerUserId', right_on='AccountId', how='inner')
df_pd_3 = tmp.loc[(tmp.OwnerUserId != -1) ,["TagName","Count","OwnerUserId","Location","DisplayName"]] \
            .sort_values("Count", ascending=False) \
            .reset_index(drop=True)
df_pd_3
# Out:
#                     TagName  Count  OwnerUserId                    Location  \
# 0                 freewheel    167       3021.0              Moscow, Russia
# 1  preventative-maintenance     62       7044.0  Manchester, United Kingdom
# 2                   7-speed     21       7044.0  Manchester, United Kingdom
# 3                       lbs     15       3649.0                         NaN
# 4               reliability      5       3927.0   Liverpool, United Kingdom
# 5                  sociable      2       7044.0  Manchester, United Kingdom
# 6                  ordinary      1       7044.0  Manchester, United Kingdom
# 7                   dicycle      1       7044.0  Manchester, United Kingdom
#
#   DisplayName
# 0         jfs
# 1    Codebeef
# 2    Codebeef
# 3         Tim
# 4  Will Boyce
# 5    Codebeef
# 6    Codebeef
# 7    Codebeef

# %%
df_pd_3.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_pd_3.equals(df_sql_3)
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe.

# %% [markdown]
# # Zadanie 4

# %% [markdown]
# Interpretacja: Dla postów z pytaniami otrzymujemy informację na temat tytułu postu oraz liczbie innych postów z nim połączonych. Sortujemy malejąco po liczbie postów połaczonych z danym postem, dzięki czemu otrzymujemy informację na temat popularności postu.

# %%
df_sql_4 = pd.read_sql_query("""SELECT Posts.Title, RelatedTab.NumLinks 
FROM
(SELECT RelatedPostId AS PostId, COUNT(*) AS NumLinks
FROM PostLinks GROUP BY RelatedPostId) AS RelatedTab
JOIN Posts ON RelatedTab.PostId=Posts.Id
WHERE Posts.PostTypeId=1
ORDER BY NumLinks DESC""", conn)

# %%
df_pd_4 = pd.merge(PostLinks.groupby("RelatedPostId").size().reset_index(name="NumLinks").rename(columns={"RelatedPostId": "PostId"}),Posts.loc[(Posts.PostTypeId==1)], left_on='PostId', right_on ='Id', how='inner')[["Title", "NumLinks"]].sort_values("NumLinks", ascending=False).reset_index(drop=True)
df_pd_4
# Out:
#                                                   Title  NumLinks
# 0     Terminology index - a list of bike part names ...       156
# 1     Why shouldn't I care what model/make/year my b...       154
# 2            How can I tell what year my bike was made?       100
# 3     What is the maximum or minimum tire width I ca...        42
# 4     Front suspension or full suspension mountain bike        37
# 5     Picking a bike for a cyclist new to riding on ...        33
# 6     What are the differences (and their practical ...        33
# 7                 Bike recommendation for daily commute        32
# 8                           Advice on buying a new bike        32
# 9              What makes a good entry level road bike?        30
# 10                         How are tire sizes measured?        29
# 11    What bike+equipment for a long daily urban com...        28
# 12             How can one estimate drag for a bicycle?        22
# 13    What should I look for when buying a used bicy...        20
# 14    How much does bike price correspond with maint...        18
# 15                         What is the optimal cadence?        16
# 16             What's your most useful cycle accessory?        15
# 17          How do I make my rim brakes stop squealing?        15
# 18                    Locking your bike in public areas        14
# 19    How do you tell what brand/make/model of bike ...        14
# 20     Upgrading straight handlebars to drop handlebars        14
# 21          What to use to clean your chain (and cogs)?        13
# 22    How do I know whether my bike can use disk bra...        12
# 23    What pressure should I run my Road Bike tyres at?        12
# 24           How do I gear up a bike for winter riding?        11
# 25      Best type of bike lock (materials, style, etc.)        11
# 26               Whatever happened to solid bike tubes?        11
# 27    What are the reasons for and against wearing a...        11
# 28              Best ways to avoid getting hit by cars?        11
# 29                                 Setting chain length        10
# ...                                                 ...       ...
# 2177   Protecting carbon bike frame after a small chip?         1
# 2178           Can someone help identify my bike frame?         1
# 2179  Whats the difference between a cyclocross and ...         1
# 2180  Is there a polite way to take the centre of th...         1
# 2181  How to protect yourself from pollution in city...         1
# 2182  Why doesn't Shimano use shadow technology on r...         1
# 2183  Why and how much is riding big-chainring-frong...         1
# 2184  What does vulcanizing solution in patch kits c...         1
# 2185                     tricycle engine compatibility?         1
# 2186  When Mark Cavendish says he's sprints at 1500 ...         1
# 2187  What am I supposed to do when my chain falls off?         1
# 2188  Do I Install Tape or Valve First on a Tubeless...         1
# 2189                      Shimano Deore Squeaking Sound         1
# 2190  Burley Flex Connector, square tube vs round tu...         1
# 2191  changing disc brake pad material while keeping...         1
# 2192             How to prevent my chain from breaking?         1
# 2193               Mountain biking: How to ride in mud?         1
# 2194      Usage experience with anti-theft GPS trackers         1
# 2195                      26" vs 28" wheels for touring         1
# 2196                          Drop Bar for Lespo Frame?         1
# 2197                  Should rotors have no rub at all?         1
# 2198  Will increased weight make me go downhill faster?         1
# 2199         How much does non-ideal frame size matter?         1
# 2200         Is it a good idea to buy a 7-year-old MTB?         1
# 2201  What's a safer alternative to a flag for marki...         1
# 2202  I am about to buy a new bicycle - what should ...         1
# 2203                   Disassembly and Shipping of bike         1
# 2204                Rotating two chains on one cassette         1
# 2205  I was in a collision the other day. What shoul...         1
# 2206  Why is a tandem harder to ride uphill than a s...         1
#
# [2207 rows x 2 columns]

# %%
df_pd_4.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_pd_4.sort_values("Title").reset_index(drop=True).equals(df_sql_4.sort_values("Title").reset_index(drop=True))
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe z dokładnością do permutacji wierszy wynikowych ramek danych. Możliwość takiego porównania uzyskujemy dzięki posortowaniu tabel po unikalnej kolumnie, czyli w tym przypadku po tytule.

# %% [markdown]
# # Zadanie 5

# %% [markdown]
# Interpretacja: Tutaj zmieniamy informację otrzymaną w pierwszym zapytaniu, dodając informację o tytule postu oraz biorąc jedynie posty z pytaniami. Dodatkowo sortujemy malejąco po kolumnie UpVotes, dzięki czemu otrzymujemy ranking tytułów pytań pod kątem "kliknięć w górę".

# %%
df_sql_5 = pd.read_sql_query("""SELECT UpVotesTab.*, Posts.Title FROM
(SELECT PostId, COUNT(*) AS UpVotes FROM Votes WHERE VoteTypeId=2 GROUP BY PostId) AS UpVotesTab
JOIN Posts ON UpVotesTab.PostId=Posts.Id
WHERE Posts.PostTypeId=1
ORDER BY UpVotesTab.UpVotes DESC""", conn)

# %%
UpVotesTab = Votes.loc[(Votes.VoteTypeId == 2)].groupby("PostId").size().reset_index(name="UpVotes")
df_pd_5 = pd.merge(UpVotesTab,Posts.loc[(Posts.PostTypeId==1)], left_on='PostId',right_on='Id')[["PostId","UpVotes","Title"]].sort_values("UpVotes", ascending=False).reset_index(drop=True)
df_pd_5
# Out:
#        PostId  UpVotes                                              Title
# 0        1980      174                        Why ride a fixed-gear bike?
# 1         244      167  Terminology index - a list of bike part names ...
# 2        8233      110  How do I deal with a dog chasing me when I'm t...
# 3         308      103           How to clean up at work after a commute?
# 4        2294       94  Safety data: Which is safer, head/tail lights ...
# 5        1500       92            Why are disc brakes rare on road bikes?
# 6        2446       87  Why do cyclists prefer messenger bags over bac...
# 7       57082       79          How to pass a bicycle while driving a car
# 8        2170       79           Is pollution a problem in urban cycling?
# 9       14372       77                        Can I use WD-40 on my bike?
# 10      15594       74              How to ride to work without sweating?
# 11       9033       72  Why is it safer to bike with traffic, instead ...
# 12       7661       70  Why aren't Tour de France riders going any fas...
# 13      10918       65  Do skilled cyclists really "use the front brak...
# 14        592       63  When or how often should I replace my bike hel...
# 15       2096       62  What advanced cycling skills are useful for a ...
# 16       1426       62               Can I ride home with a broken spoke?
# 17        623       60     Is listening to music dangerous while cycling?
# 18       1743       58  Why don't cyclists wear all-encompassing motor...
# 19       5251       58               How to use drop handlebars properly?
# 20        452       58  What is the best method to teach a young child...
# 21         89       56       Periodic Maintenance Task for Bike Commuters
# 22      16814       55  What's the difference between All-Mountain, Cr...
# 23      38530       55                           How to prevent drafting?
# 24      32131       54   How to commute to work on your bike and dress up
# 25        564       54  Can you be ticketed for breaking the speed lim...
# 26         27       53          What type of tires can prevent goatheads?
# 27        296       53  How can I make my bike (and myself) visible at...
# 28      13813       52               Hydraulic Vs. Mechanical disc brakes
# 29      18713       52  What are the effects of completely filling tir...
# ...       ...      ...                                                ...
# 11952   52564        1  How to increase friction on a Shimano SIS+Fric...
# 11953   42080        1  How to gauge pressure w/ Presta valve and Schr...
# 11954   52578        1  How to ship a full suspension bike frame witho...
# 11955   29123        1                     Having the fork blades aligned
# 11956   52593        1          Is Mustache bar for daily ride advisable?
# 11957   16855        1    Road bike getting punctured often on poor roads
# 11958   16936        1  Could I have damaged the bearings/cone when re...
# 11959   52497        1                   Hydraulic brake not working well
# 11960   52373        1  I have got 29er tires and I want to upgrade to...
# 11961   52495        1            flight deck st 4400 shifter replacement
# 11962   28965        1  Is it safe to use painted unmachine rims with ...
# 11963   28970        1  Is the Park Tool Allen Wrench going to strip o...
# 11964   16991        1                Storing spare tube under saddle bag
# 11965   52398        1                       Can I make this bike fit me?
# 11966   16988        1               Is it okay to use mismatching tires?
# 11967   52409        1  Why don't professional cyclists use the Maffet...
# 11968   29000        1  San Francisco Bay Trail: current map of comple...
# 11969   52419        1                               Bum-off-seat cycling
# 11970   42149        1  Bottom bracket tool for Shimano BB-R60 Ultegra...
# 11971   52426        1                 Compatible crankset - Giant Iguana
# 11972   16966        1      Bought slightly too big outer tube - options?
# 11973   29006        1        Which gears not to use in a 2 X 9 gear bike
# 11974   52459        1               Schwinn sidewinder 21 gear slipping?
# 11975   42144        1           Replacement crankset SRAM 3x for 10 cogs
# 11976   42138        1  Upper pulley on rear derailleur (jockey?) very...
# 11977   16947        1  Are New York pedestrians allowed to use bike l...
# 11978   29049        1            Retrofit lockout for a suspension fork?
# 11979   29060        1  Can a 7 speed Derailleur work on a 8 speed cas...
# 11980   29072        1  3 flats in 650 miles (1030 km) on hybrid bike....
# 11981   63929        1  How to use cheap nut and bolt bike with a smar...
#
# [11982 rows x 3 columns]

# %%
df_pd_5.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_pd_5.sort_values("Title").reset_index(drop=True).equals(df_sql_5.sort_values("Title").reset_index(drop=True))
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe z dokładnością do permutacji wierszy wynikowych ramek danych. Możliwość takiego porównania uzyskujemy dzięki posortowaniu tabel po unikalnej kolumnie, czyli w tym przypadku po tytule.

# %% [markdown]
# # Zadanie 6

# %% [markdown]
# Komentarz:
# Złączenie typu LEFT JOIN pozwala nam na uwzględnienie w wyniku danych, które nie posiadają swoich odpowiedników w złączanych tabelach. Oznacza to, że jeśli w pierwszej tabeli pojawiają się wiersze, które nie posiadają odpowiedników w drugiej tabeli to zostaną wzięte pod uwagę podczas złączenia ale puste kolumny zostaną wypełnione wartościami NULL (lub NaN).
#
# Interpretacja: Do tabeli z zadania pierwszego dołączamy tabelę, która zlicza DownVotes, czyli zlicza dla danego postu ilość "kliknięć w dół" (VoteTypeId=3).
#
# W kolumnie DownVotes wartości NaN pojawiły się prawdopodobnie ze względu na to, że dany post nie miał żadnych "kliknięć w dół", wobec tego uzupełniamy kolumnę DownVotes wartością 0.
#
# Uzyskujemy zatem informację o tym, ile dany post miał "kliknięć w górę", a ile "kliknięć w dół".

# %%
df_sql_6 = pd.read_sql_query("""SELECT UpVotesTab.PostId, UpVotesTab.UpVotes, IFNULL(DownVotesTab.DownVotes, 0) AS DownVotes
FROM
(SELECT PostId, COUNT(*) AS UpVotes FROM Votes
WHERE VoteTypeId=2 GROUP BY PostId) AS UpVotesTab
LEFT JOIN
(SELECT PostId, COUNT(*) AS DownVotes FROM Votes
WHERE VoteTypeId=3 GROUP BY PostId) AS DownVotesTab
ON UpVotesTab.PostId=DownVotesTab.PostId""", conn)

# %%
UpVotesTab = Votes.loc[(Votes.VoteTypeId == 2)].groupby("PostId").size().reset_index(name = "UpVotes")
DownVotesTab = Votes.loc[(Votes.VoteTypeId == 3)].groupby("PostId").size().reset_index(name = "DownVotes")
df_pd_6 = pd.merge(UpVotesTab, DownVotesTab, on = "PostId", how = "left")
df_pd_6["DownVotes"] = df_pd_6["DownVotes"].fillna(value =0).astype('int64')
df_pd_6
# Out:
#        PostId  UpVotes  DownVotes
# 0           1       42          0
# 1           2       13          0
# 2           3       10          0
# 3           4       16          0
# 4           5       31          0
# 5           6       22          0
# 6           7        4          0
# 7           8       10          0
# 8           9        3          0
# 9          10        5          1
# 10         12        3          0
# 11         13        9          0
# 12         14       16          0
# 13         15        2          0
# 14         16        7          1
# 15         17       10          0
# 16         18       12          0
# 17         19        1          0
# 18         20       15          0
# 19         21        1          0
# 20         22        2          0
# 21         23       16          0
# 22         24       35          0
# 23         25        5          0
# 24         26       21          0
# 25         27       53          0
# 26         28       15          0
# 27         29       42          0
# 28         30        1          1
# 29         31        5          0
# ...       ...      ...        ...
# 41751   63891        5          0
# 41752   63892        2          0
# 41753   63893        1          0
# 41754   63895        2          0
# 41755   63897        1          0
# 41756   63898        2          0
# 41757   63900        1          0
# 41758   63902        2          0
# 41759   63904        3          0
# 41760   63910        3          0
# 41761   63911        2          0
# 41762   63912        1          0
# 41763   63913        4          0
# 41764   63914        2          0
# 41765   63915        1          0
# 41766   63916        1          1
# 41767   63918        1          0
# 41768   63921        1          0
# 41769   63922        1          0
# 41770   63923        1          0
# 41771   63924        4          0
# 41772   63926        1          0
# 41773   63927        1          0
# 41774   63929        1          0
# 41775   63931        2          0
# 41776   63933        2          0
# 41777   63934        1          0
# 41778   63939        1          0
# 41779   63940        1          0
# 41780   63941        1          0
#
# [41781 rows x 3 columns]

# %%
df_pd_6.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_sql_6.equals(df_pd_6)
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe.

# %% [markdown]
# # Zadanie 7

# %% [markdown]
# Komentarz: Złączenie typu RIGHT JOIN działa analogicznie do LEFT JOIN, ale w tabeli wynikowej uwzględnia wiersze z drugiej tabeli, które nie posiadają odpowiedników w pierwszej.
#
# Interpretacja: Łączymy poziomo (UNION) tabelę z zadania 6. z podobną tabelą, z tym że ta druga różni się w zapytaniu tylko tym, że tak naprawdę wykonujemy teraz RIGHT JOIN w miejscu LEFT JOIN.
#
# Wobec tego nasz wynik z zadania 6. zostaje poszerzony o posty, które nie miały "kliknięć w górę", ale miały "klknięcia w dół".
# Finalnie wynik przedstawiamy w postaci dwóch kolumn: Id posta oraz Votes, która jest różnicą "kliknięć w górę" i "kliknięć w dół", wobec czego otrzymujemy informację, czy post jest bardziej lubiany lub nielubiany.

# %%
df_sql_7 = pd.read_sql_query("""SELECT PostId, UpVotes-DownVotes AS Votes FROM (
SELECT UpVotesTab.PostId, UpVotesTab.UpVotes, IFNULL(DownVotesTab.DownVotes, 0) AS DownVotes
FROM
(SELECT PostId, COUNT(*) AS UpVotes FROM Votes
WHERE VoteTypeId=2 GROUP BY PostId) AS UpVotesTab
LEFT JOIN
(SELECT PostId, COUNT(*) AS DownVotes
FROM Votes WHERE VoteTypeId=3 GROUP BY PostId) AS DownVotesTab
ON UpVotesTab.PostId=DownVotesTab.PostId
UNION
SELECT DownVotesTab.PostId, IFNULL(UpVotesTab.UpVotes, 0) AS UpVotes, DownVotesTab.DownVotes
FROM
(SELECT PostId, COUNT(*) AS DownVotes FROM Votes
WHERE VoteTypeId=3 GROUP BY PostId) AS DownVotesTab
LEFT JOIN
(SELECT PostId, COUNT(*) AS UpVotes FROM Votes
WHERE VoteTypeId=2 GROUP BY PostId) AS UpVotesTab
ON DownVotesTab.PostId=UpVotesTab.PostId
)""", conn)

# %%
df_pd_6_1 = pd.merge(UpVotesTab, DownVotesTab, on = "PostId", how = "right")
df_pd_6_1["UpVotes"] = df_pd_6_1["UpVotes"].fillna(0).astype(int)
df = pd.concat([df_pd_6, df_pd_6_1], ignore_index = True)
df['Votes'] = df['UpVotes'] - df['DownVotes']
df_pd_7 = df[["PostId", "Votes"]].drop_duplicates().sort_values("PostId").reset_index(drop = True)
df_pd_7
# Out:
#        PostId  Votes
# 0           1     42
# 1           2     13
# 2           3     10
# 3           4     16
# 4           5     31
# 5           6     22
# 6           7      4
# 7           8     10
# 8           9      3
# 9          10      4
# 10         11     -1
# 11         12      3
# 12         13      9
# 13         14     16
# 14         15      2
# 15         16      6
# 16         17     10
# 17         18     12
# 18         19      1
# 19         20     15
# 20         21      1
# 21         22      2
# 22         23     16
# 23         24     35
# 24         25      5
# 25         26     21
# 26         27     53
# 27         28     15
# 28         29     42
# 29         30      0
# ...       ...    ...
# 45679   63895      2
# 45680   63897      1
# 45681   63898      2
# 45682   63900      1
# 45683   63902      2
# 45684   63903     -1
# 45685   63904      3
# 45686   63910      3
# 45687   63911      2
# 45688   63912      1
# 45689   63913      4
# 45690   63914      2
# 45691   63915      1
# 45692   63916      0
# 45693   63918      1
# 45694   63921      1
# 45695   63922      1
# 45696   63923      1
# 45697   63924      4
# 45698   63925     -7
# 45699   63926      1
# 45700   63927      1
# 45701   63929      1
# 45702   63930     -1
# 45703   63931      2
# 45704   63933      2
# 45705   63934      1
# 45706   63939      1
# 45707   63940      1
# 45708   63941      1
#
# [45709 rows x 2 columns]

# %%
df_pd_7.__class__
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Wyniki są klasy DataFrame.

# %%
df_pd_7.equals(df_sql_7)
# Out:
# True

# %% [markdown]
# Tabele przedstawiające dwie metody implementacji są sobie równe.
